# %% [markdown]
# ## Imports

# %%
# Required for autocnet imports
import os
os.environ['ISISROOT'] = '/usgs/cpkgs/anaconda3_linux/envs/isis3.9.0'

# Autocnet Imports
from autocnet.graph.network import NetworkCandidateGraph

# Helpful Python Modules
import matplotlib.pyplot as plt  #     plotting package
import numpy as np               #     numerical computing package

# %% [markdown]
# ## Ingestion of network for analysis outside of DB

# %% [markdown]
# #### If you just want to explore your network without the benefit of DB queries, you can ingest the network into a pandas DataFrame

# %%
from plio.io.io_controlnetwork import from_isis

cnet_path = '/work/projects/kaguya/ladoramkershner/Control/imagenet/Ground/grounded_rr_jig1_ERR_PROP.net'
cnet_df = from_isis(cnet_path)

# %%
# Preview of the Data
cnet_df.head()
# Out:
#                                            id  pointType pointChoosername  \
# 0  TC2W2B0_01_05183N276E0073_bndry_8_kag_ap15          2          cnetadd
# 1  TC2W2B0_01_05183N276E0073_bndry_8_kag_ap15          2          cnetadd
# 2  TC2W2B0_01_05183N276E0073_bndry_8_kag_ap15          2          cnetadd
# 3  TC2W2B0_01_05183N276E0073_bndry_8_kag_ap15          2          cnetadd
# 4  TC2W2B0_01_05183N276E0073_bndry_8_kag_ap15          2          cnetadd
#
#          pointDatetime  pointEditLock  pointIgnore  pointJigsawRejected  \
# 0  2020-02-21T10:48:15          False        False                False
# 1  2020-02-21T10:48:15          False        False                False
# 2  2020-02-21T10:48:15          False        False                False
# 3  2020-02-21T10:48:15          False        False                False
# 4  2020-02-21T10:48:15          False        False                False
#
#    referenceIndex  aprioriSurfPointSource aprioriSurfPointSourceFile  ...  \
# 0               0                       2                             ...
# 1               0                       2                             ...
# 2               0                       2                             ...
# 3               0                       2                             ...
# 4               0                       2                             ...
#
#        measureDatetime measureEditLock  measureIgnore  measureJigsawRejected  \
# 0  2020-02-21T10:48:15           False          False                  False
# 1  2020-02-21T10:48:15           False          False                  False
# 2  2020-02-21T10:48:15           False          False                  False
# 3  2020-02-21T10:48:15           False          False                  False
# 4  2020-02-21T10:48:15           False          False                  False
#
#    diameter  apriorisample  aprioriline  samplesigma linesigma  \
# 0       0.0      -0.500000    -0.500000          0.0       0.0
# 1       0.0     715.132345  4141.660587          0.0       0.0
# 2       0.0     715.279270    53.494950          0.0       0.0
# 3       0.0    3833.369156  4174.652836          0.0       0.0
# 4       0.0    3833.369178    86.651571          0.0       0.0
#
#                                           measureLog
# 0                                                 []
# 1  [MinimumPixelZScore: -0.8449085761572315, Maxi...
# 2  [MinimumPixelZScore: -0.8449085761572315, Maxi...
# 3  [MinimumPixelZScore: -0.8449085761572315, Maxi...
# 4  [MinimumPixelZScore: -0.8449085761572315, Maxi...
#
# [5 rows x 41 columns]

# %%
# Exhaustive list of available data columns
cnet_df.columns
# Out:
# Index(['id', 'pointType', 'pointChoosername', 'pointDatetime', 'pointEditLock',
#        'pointIgnore', 'pointJigsawRejected', 'referenceIndex',
#        'aprioriSurfPointSource', 'aprioriSurfPointSourceFile',
#        'aprioriRadiusSource', 'aprioriRadiusSourceFile', 'latitudeConstrained',
#        'longitudeConstrained', 'radiusConstrained', 'aprioriX', 'aprioriY',
#        'aprioriZ', 'aprioriCovar', 'adjustedX', 'adjustedY', 'adjustedZ',
#        'adjustedCovar', 'pointLog', 'serialnumber', 'measureType', 'sample',
#        'line', 'sampleResidual', 'lineResidual', 'measureChoosername',
#        'measureDatetime', 'measureEditLock', 'measureIgnore',
#        'measureJigsawRejected', 'diameter', 'apriorisample', 'aprioriline',
#        'samplesigma', 'linesigma', 'measureLog'],
#       dtype='object')

# %%
cnet_df[["lineResidual","sampleResidual"]].describe()
# Out:
#         lineResidual  sampleResidual
# count  127791.000000   127791.000000
# mean        0.000018       -0.000005
# std         0.218852        0.271797
# min        -2.037028       -1.813218
# 25%        -0.109329       -0.159428
# 50%        -0.000280        0.000647
# 75%         0.110321        0.158499
# max         1.868503        1.857513

# %%
cnet_df.loc[cnet_df["lineResidual"]>1].describe()
# Out:
#         pointType  referenceIndex  aprioriSurfPointSource  \
# count  232.000000      232.000000              232.000000
# mean     2.030172        0.012931                2.120690
# std      0.171431        0.113221                0.685725
# min      2.000000        0.000000                2.000000
# 25%      2.000000        0.000000                2.000000
# 50%      2.000000        0.000000                2.000000
# 75%      2.000000        0.000000                2.000000
# max      3.000000        1.000000                6.000000
#
#        aprioriRadiusSource      aprioriX       aprioriY       aprioriZ  \
# count           232.000000  2.320000e+02     232.000000     232.000000
# mean              2.090517  1.580024e+06  107987.686372  704589.312932
# std               0.514294  3.190015e+04   77996.998147   66260.263474
# min               2.000000  1.487051e+06  -47667.927012  591235.931659
# 25%               2.000000  1.560087e+06   46156.428634  658084.942570
# 50%               2.000000  1.586724e+06  122949.834988  695489.316544
# 75%               2.000000  1.603126e+06  173803.370467  748048.648322
# max               5.000000  1.631982e+06  236515.648328  893938.899032
#
#           adjustedX      adjustedY      adjustedZ  measureType       sample  \
# count  2.320000e+02     232.000000     232.000000   232.000000   232.000000
# mean   1.580117e+06  108070.293150  704380.231898     2.948276  1902.869146
# std    3.190836e+04   78017.547944   66262.156083     0.391353  1320.315070
# min    1.487267e+06  -47753.354993  591026.287670     0.000000     5.776812
# 25%    1.560166e+06   46161.086235  658100.536003     3.000000   628.663097
# 50%    1.586879e+06  123142.295958  695164.129336     3.000000  1947.427382
# 75%    1.603285e+06  173889.507256  747955.241302     3.000000  3146.630403
# max    1.632044e+06  236568.201030  893572.080666     3.000000  4084.629952
#
#               line  sampleResidual  lineResidual  diameter  apriorisample  \
# count   232.000000      232.000000    232.000000     232.0     232.000000
# mean   2597.974823        0.020947      1.258120       0.0    1849.700417
# std    1619.308603        0.421322      0.227402       0.0    1313.812249
# min       5.479192       -1.344015      1.001441       0.0      -0.500000
# 25%    1081.348684       -0.208538      1.085565       0.0     611.637255
# 50%    2843.005324        0.047050      1.190890       0.0    1928.489992
# 75%    4109.715699        0.286037      1.376353       0.0    3043.880969
# max    4650.011513        1.105866      1.868503       0.0    4083.809482
#
#        aprioriline  samplesigma  linesigma
# count   232.000000        232.0      232.0
# mean   2548.152273          0.0        0.0
# std    1647.253246          0.0        0.0
# min      -0.500000          0.0        0.0
# 25%     987.731060          0.0        0.0
# 50%    2752.322157          0.0        0.0
# 75%    4111.017370          0.0        0.0
# max    4651.558629          0.0        0.0

# %% [markdown]
# #### Visualize Residuals

# %%
# list comprehension to resolve line/sample residuals
res = [np.linalg.norm((i, j)) for i, j in zip(cnet_df['sampleResidual'].values, cnet_df['lineResidual'].values)]


# Example Plot 
fig, axs = plt.subplots(1, 2, figsize=(15, 10))

axs[0].hist(res, bins=100);
axs[0].grid();
axs[0].set_xlabel('Residual Magnitude', size=16);
axs[0].set_ylabel('Occurances', size=16);
axs[0].set_title('Residual Value Histogram', size=18);

point_color=np.array([0,0,1,0.01])
point_colors=res/np.max(res)
axs[1].scatter(cnet_df['sampleResidual'].values, cnet_df['lineResidual'].values, c=point_colors, cmap="seismic");
axs[1].grid();
axs[1].set_aspect("equal")
axs[1].set_xlabel('Sample Residual', size=16);
axs[1].set_ylabel('Line Residual', size=16);
axs[1].set_title('Sample/Line Residual Distribution', size=18);

# %% [markdown]
# ## Config

# %% [markdown]
# -Configuration files in AutoCNet can run in two ways.
#
# -The first is as a dictionary.  In dictionary, you can have nested dictionaries (values of dictionaries are other dictionaries).
# -This next cell took the config.yml file, read it in, and converted it to a dictionary.
#
# -The second way is just to put the file name directly in.

# %%
# Config setup option 1
from autocnet.config_parser import parse_config

config_path = 'config.yml'
config = parse_config(config_path)

# %%
import pprint
pprint.pprint(config)
# Out:
# {'cluster': {'cluster_log_dir': '/logs',
#              'cluster_submission': 'slurm',
#              'extractor_memory': 8192,
#              'maxfailures': 3,
#              'processing_memory': 1024,
#              'queue': 'shortall',
#              'tmp_scratch_dir': '/scratch'},
#  'database': {'host': 'autocnet.wr.usgs.gov',
#               'name': 'bhw_isis_ingest_tutorial',
#               'password': 'abcde',
#               'pgbouncer_port': 30001,
#               'port': 5432,
#               'timeout': 500,
#               'type': 'postgresql',
#               'username': 'jay'},
#  'directories': {'vrt_dir': '/scratch/vrts'},
#  'env': {'ISISDATA': '/usgs/cpkgs/isis3/data',
#          'ISISROOT': '/usgs/cpkgs/anaconda3_linux/envs/isis3.9.0',
#          'conda': 'autocnet'},
#  'pfeffernusse': {'url': 'http://pfeffer.wr.usgs.gov/v1/pds'},
#  'redis': {'basename': 'bhw_ISISingest',
#            'completed_queue': 'bhw_ii:done',
#            'host': 'localhost',
#            'port': '8084',
#            'processing_queue': 'bhw_ii:proc',
#            'working_queue': 'bhw_ii:working'},
#  'spatial': {'dem': None,
#              'latitudinal_srid': 949900,
#              'proj4_str': '+proj:longlat +a:3396190 +b:3376200 +no_defs',
#              'rectangular_srid': 949980,
#              'semimajor_rad': 3396190,
#              'semiminor_rad': 3376200,
#              'target': 'MARS'}}

# %% [markdown]
# ## Ingest Database

# %% [markdown]
# -cnet_path is the path to the control network.
#
# -lis_path is the path to the image files.
#
# -Image files need to have footprintinit run on all of them prior to ingestion by autocnet.

# %%
cnet_path = "/work/projects/kaguya/ladoramkershner/Control/imagenet/Ground/grounded_rr_jig1_ERR_PROP.net"

lis_path = "/scratch/jmapel/autocnet_tut/cubes.lis"

# %% [markdown]
# -Next cell is the real meat, ingesting the images.
#
# -This cell paths to the list file, then to the config file, and dumps the contents of the database if it already exists (clear_db=TRUE).
#
# -This cell also computes another command to find all overlaping regions for the images.
#
# -This can all be done in parallal to speed up processing time.

# %%
ncg = NetworkCandidateGraph.from_filelist(lis_path, config, clear_db=True)
# Out:
# /work/users/bhwheeler/miniconda3/envs/autocnet/lib/python3.7/site-packages/autocnet-0.2.6-py3.7.egg/autocnet/graph/network.py:2119: UserWarning: Failed to reset primary id sequence for table costs
#   warnings.warn(f'Failed to reset primary id sequence for table {t}')
# loading 1 of 375
# /work/users/bhwheeler/miniconda3/envs/autocnet/lib/python3.7/site-packages/sqlalchemy/orm/relationships.py:1997: SAWarning: Setting backref / back_populates on relationship Overlay.points to refer to viewonly relationship Points.overlay should include sync_backref=False set on the Overlay.points relationship.  (this warning may be suppressed after 10 occurrences)
#   (rel_b, rel_a, rel_b),
# /work/users/bhwheeler/miniconda3/envs/autocnet/lib/python3.7/site-packages/sqlalchemy/orm/relationships.py:1997: SAWarning: Setting backref / back_populates on relationship Points.overlay to refer to viewonly relationship Overlay.points should include sync_backref=False set on the Points.overlay relationship.  (this warning may be suppressed after 10 occurrences)
#   (rel_b, rel_a, rel_b),
# loading 2 of 375
# loading 3 of 375
# loading 4 of 375
# loading 5 of 375
# loading 6 of 375
# loading 7 of 375
# loading 8 of 375
# loading 9 of 375
# loading 10 of 375
# loading 11 of 375
# loading 12 of 375
# loading 13 of 375
# loading 14 of 375
# loading 15 of 375
# loading 16 of 375
# loading 17 of 375
# loading 18 of 375
# loading 19 of 375
# loading 20 of 375
# loading 21 of 375
# loading 22 of 375
# loading 23 of 375
# loading 24 of 375
# loading 25 of 375
# loading 26 of 375
# loading 27 of 375
# loading 28 of 375
# loading 29 of 375
# loading 30 of 375
# loading 31 of 375
# loading 32 of 375
# loading 33 of 375
# loading 34 of 375
# loading 35 of 375
# loading 36 of 375
# loading 37 of 375
# loading 38 of 375
# loading 39 of 375
# loading 40 of 375
# loading 41 of 375
# loading 42 of 375
# loading 43 of 375
# loading 44 of 375
# loading 45 of 375
# loading 46 of 375
# loading 47 of 375
# loading 48 of 375
# loading 49 of 375
# loading 50 of 375
# loading 51 of 375
# loading 52 of 375
# loading 53 of 375
# loading 54 of 375
# loading 55 of 375
# loading 56 of 375
# loading 57 of 375
# loading 58 of 375
# loading 59 of 375
# loading 60 of 375
# loading 61 of 375
# loading 62 of 375
# loading 63 of 375
# loading 64 of 375
# loading 65 of 375
# loading 66 of 375
# loading 67 of 375
# loading 68 of 375
# loading 69 of 375
# loading 70 of 375
# loading 71 of 375
# loading 72 of 375
# loading 73 of 375
# loading 74 of 375
# loading 75 of 375
# loading 76 of 375
# loading 77 of 375
# loading 78 of 375
# loading 79 of 375
# loading 80 of 375
# loading 81 of 375
# loading 82 of 375
# loading 83 of 375
# loading 84 of 375
# loading 85 of 375
# loading 86 of 375
# loading 87 of 375
# loading 88 of 375
# loading 89 of 375
# loading 90 of 375
# loading 91 of 375
# loading 92 of 375
# loading 93 of 375
# loading 94 of 375
# loading 95 of 375
# loading 96 of 375
# loading 97 of 375
# loading 98 of 375
# loading 99 of 375
# loading 100 of 375
# loading 101 of 375
# loading 102 of 375
# loading 103 of 375
# loading 104 of 375
# loading 105 of 375
# loading 106 of 375
# loading 107 of 375
# loading 108 of 375
# loading 109 of 375
# loading 110 of 375
# loading 111 of 375
# loading 112 of 375
# loading 113 of 375
# loading 114 of 375
# loading 115 of 375
# loading 116 of 375
# loading 117 of 375
# loading 118 of 375
# loading 119 of 375
# loading 120 of 375
# loading 121 of 375
# loading 122 of 375
# loading 123 of 375
# loading 124 of 375
# loading 125 of 375
# loading 126 of 375
# loading 127 of 375
# loading 128 of 375
# loading 129 of 375
# loading 130 of 375
# loading 131 of 375
# loading 132 of 375
# loading 133 of 375
# loading 134 of 375
# loading 135 of 375
# loading 136 of 375
# loading 137 of 375
# loading 138 of 375
# loading 139 of 375
# loading 140 of 375
# loading 141 of 375
# loading 142 of 375
# loading 143 of 375
# loading 144 of 375
# loading 145 of 375
# loading 146 of 375
# loading 147 of 375
# loading 148 of 375
# loading 149 of 375
# loading 150 of 375
# loading 151 of 375
# loading 152 of 375
# loading 153 of 375
# loading 154 of 375
# loading 155 of 375
# loading 156 of 375
# loading 157 of 375
# loading 158 of 375
# loading 159 of 375
# loading 160 of 375
# loading 161 of 375
# loading 162 of 375
# loading 163 of 375
# loading 164 of 375
# loading 165 of 375
# loading 166 of 375
# loading 167 of 375
# loading 168 of 375
# loading 169 of 375
# loading 170 of 375
# loading 171 of 375
# loading 172 of 375
# loading 173 of 375
# loading 174 of 375
# loading 175 of 375
# loading 176 of 375
# loading 177 of 375
# loading 178 of 375
# loading 179 of 375
# loading 180 of 375
# loading 181 of 375
# loading 182 of 375
# loading 183 of 375
# loading 184 of 375
# loading 185 of 375
# loading 186 of 375
# loading 187 of 375
# loading 188 of 375
# loading 189 of 375
# loading 190 of 375
# loading 191 of 375
# loading 192 of 375
# loading 193 of 375
# loading 194 of 375
# loading 195 of 375
# loading 196 of 375
# loading 197 of 375
# loading 198 of 375
# loading 199 of 375
# loading 200 of 375
# loading 201 of 375
# loading 202 of 375
# loading 203 of 375
# loading 204 of 375
# loading 205 of 375
# loading 206 of 375
# loading 207 of 375
# loading 208 of 375
# loading 209 of 375
# loading 210 of 375
# loading 211 of 375
# loading 212 of 375
# loading 213 of 375
# loading 214 of 375
# loading 215 of 375
# loading 216 of 375
# loading 217 of 375
# loading 218 of 375
# loading 219 of 375
# loading 220 of 375
# loading 221 of 375
# loading 222 of 375
# loading 223 of 375
# loading 224 of 375
# loading 225 of 375
# loading 226 of 375
# loading 227 of 375
# loading 228 of 375
# loading 229 of 375
# loading 230 of 375
# loading 231 of 375
# loading 232 of 375
# loading 233 of 375
# loading 234 of 375
# loading 235 of 375
# loading 236 of 375
# loading 237 of 375
# loading 238 of 375
# loading 239 of 375
# loading 240 of 375
# loading 241 of 375
# loading 242 of 375
# loading 243 of 375
# loading 244 of 375
# loading 245 of 375
# loading 246 of 375
# loading 247 of 375
# loading 248 of 375
# loading 249 of 375
# loading 250 of 375
# loading 251 of 375
# loading 252 of 375
# loading 253 of 375
# loading 254 of 375
# loading 255 of 375
# loading 256 of 375
# loading 257 of 375
# loading 258 of 375
# loading 259 of 375
# loading 260 of 375
# loading 261 of 375
# loading 262 of 375
# loading 263 of 375
# loading 264 of 375
# loading 265 of 375
# loading 266 of 375
# loading 267 of 375
# loading 268 of 375
# loading 269 of 375
# loading 270 of 375
# loading 271 of 375
# loading 272 of 375
# loading 273 of 375
# loading 274 of 375
# loading 275 of 375
# loading 276 of 375
# loading 277 of 375
# loading 278 of 375
# loading 279 of 375
# loading 280 of 375
# loading 281 of 375
# loading 282 of 375
# loading 283 of 375
# loading 284 of 375
# loading 285 of 375
# loading 286 of 375
# loading 287 of 375
# loading 288 of 375
# loading 289 of 375
# loading 290 of 375
# loading 291 of 375
# loading 292 of 375
# loading 293 of 375
# loading 294 of 375
# loading 295 of 375
# loading 296 of 375
# loading 297 of 375
# loading 298 of 375
# loading 299 of 375
# loading 300 of 375
# loading 301 of 375
# loading 302 of 375
# loading 303 of 375
# loading 304 of 375
# loading 305 of 375
# loading 306 of 375
# loading 307 of 375
# loading 308 of 375
# loading 309 of 375
# loading 310 of 375
# loading 311 of 375
# loading 312 of 375
# loading 313 of 375
# loading 314 of 375
# loading 315 of 375
# loading 316 of 375
# loading 317 of 375
# loading 318 of 375
# loading 319 of 375
# loading 320 of 375
# loading 321 of 375
# loading 322 of 375
# loading 323 of 375
# loading 324 of 375
# loading 325 of 375
# loading 326 of 375
# loading 327 of 375
# loading 328 of 375
# loading 329 of 375
# loading 330 of 375
# loading 331 of 375
# loading 332 of 375
# loading 333 of 375
# loading 334 of 375
# loading 335 of 375
# loading 336 of 375
# loading 337 of 375
# loading 338 of 375
# loading 339 of 375
# loading 340 of 375
# loading 341 of 375
# loading 342 of 375
# loading 343 of 375
# loading 344 of 375
# loading 345 of 375
# loading 346 of 375
# loading 347 of 375
# loading 348 of 375
# loading 349 of 375
# loading 350 of 375
# loading 351 of 375
# loading 352 of 375
# loading 353 of 375
# loading 354 of 375
# loading 355 of 375
# loading 356 of 375
# loading 357 of 375
# loading 358 of 375
# loading 359 of 375
# loading 360 of 375
# loading 361 of 375
# loading 362 of 375
# loading 363 of 375
# loading 364 of 375
# loading 365 of 375
# loading 366 of 375
# loading 367 of 375
# loading 368 of 375
# loading 369 of 375
# loading 370 of 375
# loading 371 of 375
# loading 372 of 375
# loading 373 of 375
# loading 374 of 375
# loading 375 of 375

# %% [markdown]
# -This cell just checks that there are images in the database, it should spit out a number.

# %%
# Quick Check there are images in the DB
from autocnet.io.db.model import Images, Points
with ncg.session_scope() as session:
    res = session.query(Images).count()
    print(res)
# Out:
# 375

# %% [markdown]
# -At this point, it is worth checking autocnet to make sure the images have loaded correctly.
#
# -Go to: autocnet.wr.usgs.gov  (pg admin). In pg admin, go to your database/schemas/tables/images and right-click images.  Select the query tool.
#
# -Write some simple code to get everything for the image table (select * from images) and press the lightning bolt button.
#
# -Click the eyeball next to the geom column and it should show the image footprints.

# %% [markdown]
# -The next cell is to injest the control points for the images.
#
# -There will be some warnings that can be ignored for now.  This block takes about ~40 minutes to run.

# %%
ncg = NetworkCandidateGraph.from_cnet(cnet_path, lis_path, config)

# %%
from autocnet.io.db.model import Images, Points
with ncg.session_scope() as session:
    res = session.query(Points).all()
    print(len(res))
    for i in range(0,11):
        print(f'point {res[i].id} geom: ', res[i].geom)
